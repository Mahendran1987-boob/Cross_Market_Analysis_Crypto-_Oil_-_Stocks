# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahendran1987-boob/Cross_Market_Analysis_Crypto-_Oil_-_Stocks/blob/main/Cross_Market_Analysis_Crypto%2C_Oil_%26_Stocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
name = "Mahendran S"
print(f"My name is {name}")
# Out:
# My name is Mahendran S

# %%
all_records = []#250 + 250 + 250 (750-1250)
import requests  # Use string formating, and for loop and scroll through 5 pages to collect data

url = "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&per_page=250&order=market_cap_desc&page=3&sparkline=False"

response = requests.get(url)
 # 200 means your request was success
if response.status_code == 200:
  data = response.json()
  #all_records.extend(data)

  # while running this code, if you face, rate limit exceeded error, wait for 10 or 15 mins and then
  #again execute it

# %%
import requests
import pandas as pd
all_records = []

# 250 records per page × 5 pages = 1250 records
for i in range(1,6):
    url = f"https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&per_page=250&order=market_cap_desc&page={i}&sparkline=False"

    response = requests.get(url)

    if response.status_code == 200:
        data1 = response.json()
        all_records.extend(data1)

#print(data1)  # Should print 1250
ar = pd.DataFrame(data1)
ar = ar.rename(columns={'last_updated': 'Date'})
ar
# Out:
#                         id symbol                   name  \
# 0                 uchain-2    ucn                 UCHAIN
# 1               frax-share   frax       Frax (prev. FXS)
# 2                      yzy    yzy                    YZY
# 3             terra-luna-2   luna                  Terra
# 4             pirate-chain   arrr           Pirate Chain
# ..                     ...    ...                    ...
# 245                  taiko  taiko                  Taiko
# 246  kyber-network-crystal    knc  Kyber Network Crystal
# 247               humidifi    wet               HumidiFi
# 248                 corn-3   corn                   Corn
# 249          goldfish-gold   ggbr          Goldfish Gold
#
#                                                  image  current_price  \
# 0    https://coin-images.coingecko.com/coins/images...     429.710000
# 1    https://coin-images.coingecko.com/coins/images...       0.447848
# ...

# %%
import requests
import pandas as pd
import time

all_records = []

for i in range(1, 6):   # 1 to 5 (5 pages)
    url = f"https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&per_page=250&order=market_cap_desc&page={i}&sparkline=false"

    response = requests.get(url)

    print(f"Page {i} status:", response.status_code)

    if response.status_code == 200:
        data = response.json()
        print(f"Page {i} records:", len(data))
        all_records.extend(data)
    else:
        print("Error on page", i)

    time.sleep(1)   # Prevent rate limit

print("Total records:", len(all_records))
#print(data)
df = pd.DataFrame(all_records)
df

cc =  df[['id','symbol','name','current_price','market_cap','market_cap_rank','total_volume','circulating_supply','total_supply','ath','atl','last_updated']]
#cc = pd.DataFrame(cc)
cc = cc.rename(columns={'last_updated': 'Date'})
cc['Date'] = pd.to_datetime(cc['Date']).dt.strftime('%Y-%m-%d')

cc.head()
#cc = cc.rename(columns={'last_updated': 'Date'})
cc_copy = cc.copy()
cc_copy.to_csv("/content/drive/MyDrive/Cryptocurrencies.csv")
#print(df)   # Should show (750, number_of_columns)
df.head()         # View first 5 rows
# Out:
# Page 1 status: 200
# Page 1 records: 250
# Page 2 status: 200
# Page 2 records: 250
# Page 3 status: 200
# Page 3 records: 250
# Page 4 status: 429
# Error on page 4
# Page 5 status: 429
# Error on page 5
# Total records: 750
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3  binancecoin    bnb       BNB
# 4       ripple    xrp       XRP
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...   69627.000000
# 1  https://coin-images.coingecko.com/coins/images...    2079.310000
# 2  https://coin-images.coingecko.com/coins/images...       0.999558
# 3  https://coin-images.coingecko.com/coins/images...     631.180000
# 4  https://coin-images.coingecko.com/coins/images...       1.380000
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# ...

# %%
cc
# Out:
#                    id    symbol              name  current_price  \
# 0             bitcoin       btc           Bitcoin   69627.000000
# 1            ethereum       eth          Ethereum    2079.310000
# 2              tether      usdt            Tether       0.999558
# 3         binancecoin       bnb               BNB     631.180000
# 4              ripple       xrp               XRP       1.380000
# ..                ...       ...               ...            ...
# 745          pinksale  pinksale          PinkSale     237.350000
# 746  particle-network     parti  Particle Network       0.102109
# 747             anoma       xan             Anoma       0.009409
# 748        omega-labs      sn24        OMEGA Labs       5.490000
# 749          medibloc       med          Medibloc       0.002211
#
#         market_cap  market_cap_rank  total_volume  circulating_supply  \
# 0    1394957303573                1  3.909369e+10        2.000304e+07
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_5522/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
#df_copy.to_csv("/content/drive/MyDrive/coin_data.csv", index = False)
#df_copy = df.copy()

# %% [markdown]
# \# Top 3 Coins – Historical Prices

# %%
#Correct code
import pandas as pd
import requests

coin_ids = ['bitcoin', 'ethereum', 'tether']

all_prices = []

for coin in coin_ids:

    url = f"https://api.coingecko.com/api/v3/coins/{coin}/market_chart"

    params = {
        "vs_currency": "usd",
        "days": "365"
    }

    response = requests.get(url, params=params)
    r = response.json()

    df = pd.DataFrame(r['prices'], columns=['timestamp','price_usd'])

    df['date'] = pd.to_datetime(df['timestamp'], unit='ms')
    df['coin_id'] = coin

    df = df[['coin_id','date','price_usd']]

    all_prices.append(df)

crypto_prices = pd.concat(all_prices, ignore_index=True)
crypto_prices["date"] = pd.to_datetime(crypto_prices["date"]).dt.date
crypto_prices
crypto_prices = pd.concat(all_prices, ignore_index=True)
crypto_prices["date"] = pd.to_datetime(crypto_prices["date"]).dt.date
crypto_prices
crypto_prices.head()
# Out:
#    coin_id        date     price_usd
# 0  bitcoin  2025-03-27  86960.855549
# 1  bitcoin  2025-03-28  87227.271580
# 2  bitcoin  2025-03-29  84359.469155
# 3  bitcoin  2025-03-30  82679.172554
# 4  bitcoin  2025-03-31  82356.381112

# %%
crypto_prices
# Out:
#       coin_id        date     price_usd
# 0     bitcoin  2025-03-27  86960.855549
# 1     bitcoin  2025-03-28  87227.271580
# 2     bitcoin  2025-03-29  84359.469155
# 3     bitcoin  2025-03-30  82679.172554
# 4     bitcoin  2025-03-31  82356.381112
# ...       ...         ...           ...
# 1093   tether  2026-03-23      0.999760
# 1094   tether  2026-03-24      0.999728
# 1095   tether  2026-03-25      0.999546
# 1096   tether  2026-03-26      0.999616
# 1097   tether  2026-03-26      0.999551
#
# [1098 rows x 3 columns]

# %% [markdown]
# Oil Prices

# %%
'''import pandas as pd

oil_df = pd.read_csv("https://raw.githubusercontent.com/datasets/oil-prices/main/data/wti-daily.csv")

oil_df.to_csv(r"/content/drive/MyDrive/oilprices.csv", index=False)
df = pd.DataFrame(oil_df)
#cc = cc.rename(columns={'last_updated': 'Date'})
df = df.rename(columns={'Price': 'price_usd'})
df'''

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/oilprices.csv")
df
df['Date'] = pd.to_datetime(df['Date'])# format='%d-%m-%Y')
filtered_df = df[
    (df['Date'] >= '2020-01-01') &
    (df['Date'] <= '2026-01-31')
]
filtered_df['Date'] = pd.to_datetime(filtered_df['Date']).dt.strftime('%Y-%m-%d')
filtered_df = filtered_df.rename(columns={'Price': 'price_usd'})
#filtered_df = filtered_df.rename(columns={"Price": "Price_usd"})
#oil_df = filtered_df.rename(columns={"price": "price_usd"}, inplace=True)
filtered_df.to_csv(r"/content/drive/MyDrive/oilprices1.csv", index=False)
# Out:
# /tmp/ipykernel_5522/1075808767.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Date'] = pd.to_datetime(filtered_df['Date']).dt.strftime('%Y-%m-%d')

# %%
filtered_df
# Out:
#              Date  price_usd
# 8569   2020-01-02      61.17
# 8570   2020-01-03      63.00
# 8571   2020-01-06      63.27
# 8572   2020-01-07      62.70
# 8573   2020-01-08      59.65
# ...           ...        ...
# 10084  2026-01-26      60.46
# 10085  2026-01-27      62.04
# 10086  2026-01-28      62.75
# 10087  2026-01-29      64.77
# 10088  2026-01-30      64.50
#
# [1520 rows x 2 columns]

# %%
filtered_df.to_csv("oil_prices.csv",index = False) # after collecting all the data make sure to save it as a csv files

# %% [markdown]
# Stock Prices (Yahoo Finance API)

# %%
import yfinance as yf
import pandas as pd

# Choose indices
tickers = ["^GSPC", "^IXIC", "^NSEI"]
start_date = "2020-01-01"
end_date = "2025-09-30"

# Download historical data
stocks_df = yf.download(tickers, start=start_date, end=end_date, group_by="ticker")
stocks_df.head()
#stocks_df.tail()
# Out:
# /tmp/ipykernel_5522/58905462.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks_df = yf.download(tickers, start=start_date, end=end_date, group_by="ticker")
# [*********************100%***********************]  3 of 3 completed
# Ticker             ^NSEI                                                      \
# Price               Open          High           Low         Close    Volume
# Date
# 2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000  304100.0
# 2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195  407700.0
# 2020-01-03  12261.099609  12265.599609  12191.349609  12226.650391  428800.0
# 2020-01-06  12170.599609  12179.099609  11974.200195  11993.049805  396500.0
# 2020-01-07  12079.099609  12152.150391  12005.349609  12052.950195  447800.0
#
# Ticker            ^GSPC                                                       \
# ...

# %%
stocks_1 = stocks_df['^GSPC'].reset_index() # collect 3 ticker data similarly , add a new column ticker and then concat them.
# handle the  nulls
stocks_1["Ticker"] = "^GSPC"
stocks_1 = stocks_1.dropna(subset=['Close'])
stocks_1
# Out:
# Price       Date         Open         High          Low        Close  \
# 1     2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098
# 2     2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098
# 3     2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029
# 4     2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932
# 5     2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049
# ...          ...          ...          ...          ...          ...
# 1485  2025-09-23  6692.439941  6699.520020  6645.580078  6656.919922
# 1486  2025-09-24  6669.790039  6672.660156  6621.759766  6637.970215
# 1487  2025-09-25  6608.189941  6619.000000  6569.220215  6604.720215
# 1488  2025-09-26  6615.379883  6648.970215  6604.430176  6643.700195
# 1489  2025-09-29  6661.580078  6677.310059  6644.490234  6661.209961
#
# Price        Volume Ticker
# 1      3.459930e+09  ^GSPC
# 2      3.484700e+09  ^GSPC
# 3      3.702460e+09  ^GSPC
# ...

# %%
stocks_2 = stocks_df['^IXIC'].reset_index() # collect 3 ticker data similarly , add a new column ticker and then concat them.
# handle the  nulls
stocks_2["Ticker"] = "^IXIC"
stocks_2 = stocks_2.dropna(subset=['Close'])
stocks_2
# Out:
# Price       Date          Open          High           Low         Close  \
# 1     2020-01-02   9039.459961   9093.429688   9010.889648   9092.190430
# 2     2020-01-03   8976.429688   9065.759766   8976.429688   9020.769531
# 3     2020-01-06   8943.500000   9072.410156   8943.500000   9071.469727
# 4     2020-01-07   9076.639648   9091.929688   9042.549805   9068.580078
# 5     2020-01-08   9068.030273   9168.889648   9059.379883   9129.240234
# ...          ...           ...           ...           ...           ...
# 1485  2025-09-23  22782.720703  22785.130859  22539.039062  22573.470703
# 1486  2025-09-24  22656.019531  22657.449219  22397.000000  22497.859375
# 1487  2025-09-25  22318.769531  22456.779297  22185.869141  22384.699219
# 1488  2025-09-26  22403.269531  22488.179688  22285.439453  22484.070312
# 1489  2025-09-29  22605.300781  22704.900391  22536.050781  22591.150391
#
# Price        Volume Ticker
# 1      2.862700e+09  ^IXIC
# 2      2.586520e+09  ^IXIC
# ...

# %%
stocks_3 = stocks_df['^NSEI'].reset_index() # collect 3 ticker data similarly , add a new column ticker and then concat them.
# handle the  nulls
stocks_3['Ticker'] = "^NSEI"
stocks_3 = stocks_3.dropna(subset=['Close'])
stocks_3
# Out:
# Price       Date          Open          High           Low         Close  \
# 0     2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000
# 1     2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195
# 2     2020-01-03  12261.099609  12265.599609  12191.349609  12226.650391
# 3     2020-01-06  12170.599609  12179.099609  11974.200195  11993.049805
# 4     2020-01-07  12079.099609  12152.150391  12005.349609  12052.950195
# ...          ...           ...           ...           ...           ...
# 1485  2025-09-23  25209.000000  25261.900391  25084.650391  25169.500000
# 1486  2025-09-24  25108.750000  25149.849609  25027.449219  25056.900391
# 1487  2025-09-25  25034.500000  25092.699219  24878.300781  24890.849609
# 1488  2025-09-26  24818.550781  24868.599609  24629.449219  24654.699219
# 1489  2025-09-29  24728.550781  24791.300781  24606.199219  24634.900391
#
# Price    Volume Ticker
# 0      304100.0  ^NSEI
# 1      407700.0  ^NSEI
# ...

# %%
all_stocks = pd.concat([stocks_1, stocks_2, stocks_3])
all_stocks['Date'] = pd.to_datetime(all_stocks['Date']).dt.strftime('%Y-%m-%d')

# %%
all_stocks
# Out:
# Price        Date          Open          High           Low         Close  \
# 1      2020-01-02   3244.669922   3258.139893   3235.530029   3257.850098
# 2      2020-01-03   3226.360107   3246.149902   3222.340088   3234.850098
# 3      2020-01-06   3217.550049   3246.840088   3214.639893   3246.280029
# 4      2020-01-07   3241.860107   3244.909912   3232.429932   3237.179932
# 5      2020-01-08   3238.590088   3267.070068   3236.669922   3253.050049
# ...           ...           ...           ...           ...           ...
# 1485   2025-09-23  25209.000000  25261.900391  25084.650391  25169.500000
# 1486   2025-09-24  25108.750000  25149.849609  25027.449219  25056.900391
# 1487   2025-09-25  25034.500000  25092.699219  24878.300781  24890.849609
# 1488   2025-09-26  24818.550781  24868.599609  24629.449219  24654.699219
# 1489   2025-09-29  24728.550781  24791.300781  24606.199219  24634.900391
#
# Price        Volume Ticker
# 1      3.459930e+09  ^GSPC
# ...

# %%
# !pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.7 MB/s eta 0:00:00
# ...

# %%
import sqlite3
conn = sqlite3.connect("ds.db")
cursor = conn.cursor()

# %%
cc.to_sql("Cryptocurrencies",if_exists="replace",con =conn)
# Out:
# 750

# %%
crypto_prices.to_sql("Crypto_price",if_exists="replace",con =conn)
# Out:
# 1098

# %%
filtered_df.to_sql("oil_prices",if_exists="replace",con =conn)
# Out:
# 1520

# %%
all_stocks.to_sql("stock_prices",if_exists="replace",con =conn)
# Out:
# 4309

# %%
# 1. create 4 tables
# 2. Insert 4 dataframe into sql(4 tables) usinf df.iterrows and cursor
# 3. Queries

# %% [markdown]
# Streamlit demo

# %%
# !pip install -q streamlit
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64
import subprocess
subprocess.Popen(["./cloudflared-linux-amd64", "tunnel", "--url", "http://localhost:8501"])
# !nohup /content/cloudflared-linux-amd64 tunnel --url http://localhost:8501 &
# Out:
# --2026-03-26 16:37:59--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2026.3.0/cloudflared-linux-amd64 [following]
# --2026-03-26 16:37:59--  https://github.com/cloudflare/cloudflared/releases/download/2026.3.0/cloudflared-linux-amd64
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# Code

# %%
# !pip install streamlit-option-menu

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd

from streamlit_option_menu import option_menu
import sqlite3
conn = sqlite3.connect("ds.db")
cursor = conn.cursor()
st.title("💰🛢️📈Cross-Market Analysis")

with st.sidebar:
    selected = option_menu("Main Menu", ["Home", 'Filters',"Queries","Crypto Analysis"],
        icons=['house', 'gear'], menu_icon="cast", default_index=1)

if selected == "Home":
    st.write("This is my home page")
    st.write("Oil Market (e.g., Crude Oil)")
    st.write("Influences the global economy. When oil prices rise, costs increase for industries, which can reduce company profits.")
    st.write("Stock Market (e.g., S&P 500, NIFTY 50)")
    st.write("Reflects economic health. Rising oil prices often negatively impact stocks, especially transport and manufacturing sectors.")
    st.write("Cryptocurrency Market (e.g., Bitcoin, Ethereum)")
    st.write("Highly volatile and sometimes behaves independently, but can follow stock market trends during major economic events.")

if selected == "Filters":
     st.header("Crypto Oil Stock Market Analytics")
     filtered_df = pd.read_sql("select AVG(c.price_usd) AS bitcoin_avg_price, AVG(o.price_usd) AS oil_avg_price, AVG(s.close) AS sp500_avg_close, AVG(n.close) AS nifty_avg_close FROM crypto_price c JOIN oil_prices o ON c.Date = o.Date JOIN stock_prices s ON c.Date = s.Date AND s.ticker='^GSPC' JOIN stock_prices n  ON c.Date = n.Date AND n.ticker='^NSEI' WHERE c.coin_id='bitcoin' ",con=conn)
     btc_avg = filtered_df["bitcoin_avg_price"][0]
     oil_avg = filtered_df["oil_avg_price"][0]
     sp500_avg = filtered_df["sp500_avg_close"][0]
     nifty_avg = filtered_df["nifty_avg_close"][0]
     st.subheader("Market Average Prices")
     col1,col2,col3,col4 = st.columns(4)
     col1.metric("Bitcoin Avg Price", round(btc_avg,2))
     col2.metric("Oil Avg Price", round(oil_avg,2))
     col3.metric("S&P500 Avg Close", round(sp500_avg,2))
     col4.metric("NIFTY Avg Close", round(nifty_avg,2))
     st.subheader("Daily Market Snapshot")
     filtered_df = pd.read_sql("SELECT c.date, c.price_usd AS bitcoin_price, o.price_usd AS oil_price, s.close AS sp500_close, n.close AS nifty_close FROM crypto_price c JOIN oil_prices o ON c.date = o.date JOIN stock_prices s ON c.date = s.date AND s.ticker='^GSPC' JOIN stock_prices n ON c.date = n.date AND n.ticker='^NSEI' WHERE c.coin_id='bitcoin' GROUP BY c.date ORDER BY c.date; ",con=conn)
     st.dataframe(filtered_df)

if selected == "Queries":
     option = st.selectbox(
     "Ccryptocurrencies",
    (
     "1. Find the top 3 cryptocurrencies by market cap.",
     "2.List all coins where circulating supply exceeds 90% of total supply.",
     "3. Get coins that are within 10% of their all-time-high (ATH).",
     "4. Find the average market cap rank of coins with volume above $1B.",
     "5. Get the most recently updated coin."
     )
)
     if option == "1. Find the top 3 cryptocurrencies by market cap.":
         filtered_df = pd.read_sql("SELECT name, symbol, market_cap FROM Cryptocurrencies ORDER BY market_cap DESC LIMIT 3",con=conn)
         st.dataframe(filtered_df)
     if option == "2.List all coins where circulating supply exceeds 90% of total supply.":
         filtered_df = pd.read_sql("SELECT name, symbol, circulating_supply, total_supply FROM Cryptocurrencies WHERE circulating_supply >= 0.9 * total_supply;",con=conn)
         st.dataframe(filtered_df)
     if option == "3. Get coins that are within 10% of their all-time-high (ATH).":
         filtered_df = pd.read_sql("SELECT name, symbol, current_price, ath FROM cryptocurrencies WHERE CAST(current_price AS REAL) >= 0.9 * CAST(ath AS REAL);",con=conn)
         st.dataframe(filtered_df)
     if option == "4. Find the average market cap rank of coins with volume above $1B.":
         filtered_df = pd.read_sql("SELECT AVG(market_cap_rank) AS avg_market_cap_rank FROM cryptocurrencies WHERE Date > 1000000000;",con=conn)
         st.dataframe(filtered_df)
     if option == "5. Get the most recently updated coin.":
         filtered_df = pd.read_sql("SELECT  * FROM cryptocurrencies ORDER BY Date DESC LIMIT 1;",con=conn)
         st.dataframe(filtered_df)

#crypto_prices
#st.title("Crypto Prices")
if selected == "Queries":
     option = st.selectbox(
     "crypto_prices",
    (
     "1. Find the highest daily price of Bitcoin in the last 365 days.",
     "2. Calculate the average daily price of Ethereum in the past 1 year.",
     "3. Show the daily price trend of Bitcoin in January 2025",
     "4. Find the coin with the highest average price over 1 year.",
     "5. Get the % change in Bitcoin’s price between Sep 2024 and Sep 2025."
     )
)
     if option == "1. Find the highest daily price of Bitcoin in the last 365 days.":
         crypto_prices = pd.read_sql("SELECT MAX(price_usd) AS highest_price FROM crypto_price WHERE coin_id = 'bitcoin';",con=conn)
         st.dataframe(crypto_prices)
     if option == "2. Calculate the average daily price of Ethereum in the past 1 year.":
         crypto_prices = pd.read_sql("SELECT AVG(price_usd) AS avg_price FROM crypto_price WHERE coin_id = 'ethereum'",con=conn)
         st.dataframe(crypto_prices)
     if option == "3. Show the daily price trend of Bitcoin in January 2025":
         crypto_prices = pd.read_sql(" SELECT date, price_usd FROM crypto_price WHERE coin_id = 'bitcoin' and date between '2025-01-01' and '2025-04-30' ",con = conn)
         st.dataframe(crypto_prices)
     if option == "4. Find the coin with the highest average price over 1 year.":
         crypto_prices = pd.read_sql("SELECT coin_id, AVG(price_usd) AS avg_price FROM crypto_price GROUP BY coin_id ORDER BY avg_price DESC LIMIT 1;",con=conn)
         st.dataframe(crypto_prices)
     if option == "5. Get the % change in Bitcoin’s price between Sep 2024 and Sep 2025.":
         crypto_prices = pd.read_sql("SELECT ((sep2025.price - sep2024.price) * 100.0 / sep2024.price) AS pct_change FROM (SELECT price_usd AS price FROM crypto_price WHERE coin_id = 'bitcoin' AND date BETWEEN '2024-09-01' AND '2024-09-30' ORDER BY date DESC LIMIT 1) AS sep2024,(SELECT price_usd AS price FROM crypto_price WHERE coin_id = 'bitcoin' AND date BETWEEN '2025-09-01' AND '2025-09-30' ORDER BY date DESC LIMIT 1) AS sep2025;",con=conn)
         st.dataframe(crypto_prices)

#st.title("Oil prices")
if selected == "Queries":

     option = st.selectbox(
    "Oil_prices",
    (
     "1. Find the highest oil price in the last 5 years.",
     "2. Get the average oil price per year.",
     "3. Show oil prices during COVID crash (March–April 2020).",
     "4. Find the lowest price of oil in the last 10 years.",
     "5. Calculate the volatility of oil prices (max-min difference per year).  "
     )
)

     if option == "1. Find the highest oil price in the last 5 years.":
         filtered_df = pd.read_sql("SELECT MAX(price_usd) AS highest_price FROM oil_prices WHERE date >= date('now','-5 years');",con=conn)
         st.dataframe(filtered_df)
     if option == "2. Get the average oil price per year.":
         filtered_df = pd.read_sql("SELECT strftime('%Y', date) AS year, AVG(price_usd) AS avg_price FROM oil_prices GROUP BY year ORDER BY year;",con=conn)
         st.dataframe(filtered_df)
     if option == "3. Show oil prices during COVID crash (March–April 2020).":
         filtered_df = pd.read_sql("SELECT date, price_usd FROM oil_prices WHERE date BETWEEN '2020-03-01' AND '2020-04-30' GROUP BY date ORDER BY date;",con=conn)
         st.dataframe(filtered_df)
     if option == "4. Find the lowest price of oil in the last 10 years.":
         filtered_df = pd.read_sql("SELECT MIN(price_usd) FROM oil_prices WHERE date >= date('now','-10 years');",con=conn)
         st.dataframe(filtered_df)
     if option == "5. Calculate the volatility of oil prices (max-min difference per year).":
         filtered_df = pd.read_sql("SELECT strftime('%Y', date) AS year, MAX(price_usd) - MIN(price_usd) AS volatility FROM oil_prices GROUP BY year ORDER BY year;",con=conn)
         st.dataframe(filtered_df)

#"stock_prices"
#st.title("stock_prices")
if selected == "Queries":

     option = st.selectbox(
    "stock_prices",
    (
     "1. Get all stock prices for a given ticker",
     "2. Find the highest closing price for NASDAQ (^IXIC)",
     "3. List top 5 days with highest price difference (high - low) for S&P 500 (^GSPC)",
     "4. Get monthly average closing price for each ticker",
     "5. Get average trading volume of NSEI in 2024"
     )
)

     if option == "1. Get all stock prices for a given ticker":
         all_stocks = pd.read_sql("SELECT * FROM stock_prices WHERE ticker='^NSEI';",con=conn)
         st.dataframe(all_stocks)
     if option == "2. Find the highest closing price for NASDAQ (^IXIC)":
         all_stocks = pd.read_sql("SELECT MAX(close) AS highest_close FROM stock_prices WHERE ticker='^IXIC';",con=conn)
         st.dataframe(all_stocks)
     if option == "3. List top 5 days with highest price difference (high - low) for S&P 500 (^GSPC)":
         all_stocks = pd.read_sql("SELECT date, high, low, (high-low) AS price_diff FROM stock_prices WHERE ticker='^GSPC' ORDER BY price_diff DESC LIMIT 5;",con=conn)
         st.dataframe(all_stocks)
     if option == "4. Get monthly average closing price for each ticker":
         all_stocks = pd.read_sql("SELECT strftime('%Y-%m', date) AS month, ticker, AVG(close) AS avg_close FROM stock_prices GROUP BY ticker, month ORDER BY ticker, month;",con=conn)
         st.dataframe(all_stocks)
     if option == "5. Get average trading volume of NSEI in 2024":
         all_stocks = pd.read_sql("SELECT AVG(volume) AS avg_volume FROM stock_prices WHERE ticker='^NSEI' AND strftime('%Y', date)='2024';",con=conn)
         st.dataframe(all_stocks)

if selected == "Queries":
     option = st.selectbox(
     "Join Query",
    (
     "1. Compare Bitcoin vs Oil average price in 2025.",
     "2. Check if Bitcoin moves with S&P 500 (correlation idea).",
     "3. Compare Ethereum and NASDAQ daily prices for 2025.",
     "4. Find days when oil price spiked and compare with Bitcoin price change.",
     "5. Compare top 3 coins daily price trend vs Nifty (^NSEI).",
     "6. Compare stock prices (^GSPC) with crude oil prices on the same dates",
     "7. Correlate Bitcoin closing price with crude oil closing price (same date)",
     "8. Compare NASDAQ (^IXIC) with Ethereum price trends",
     "9. Join top 3 crypto coins with stock indices for 2025",
     "10. Multi-join: stock prices, oil prices, and Bitcoin prices for daily comparison"
     )
)
     if option == "1. Compare Bitcoin vs Oil average price in 2025.":
         filtered_df = pd.read_sql("SELECT 'Bitcoin' AS Asset, AVG(price_usd) AS Avg_price_2025 FROM crypto_price WHERE strftime('%Y', date) = '2025' UNION ALL SELECT 'Oil' AS asset, AVG(price_usd) AS avg_price_2025 FROM oil_prices WHERE strftime('%Y', date) = '2025' ",con=conn)
         st.dataframe(filtered_df)
     if option == "2. Check if Bitcoin moves with S&P 500 (correlation idea).":
         filtered_df = pd.read_sql("SELECT s.date, s.close AS sp500_close, c.price_usd AS bitcoin_price FROM stock_prices s JOIN crypto_price c ON s.date = c.date WHERE s.ticker='^GSPC' AND c.coin_id='bitcoin' ORDER BY s.date",con=conn)
         st.dataframe(filtered_df)
     if option == "3. Compare Ethereum and NASDAQ daily prices for 2025.":
         filtered_df = pd.read_sql("SELECT s.date, s.close AS nasdaq_close, c.price_usd AS ethereum_price FROM stock_prices s JOIN crypto_price c ON s.date = c.date WHERE s.ticker='^IXIC' AND c.coin_id='ethereum' AND strftime('%Y', s.date)='2025' ORDER BY s.date",con=conn)
         st.dataframe(filtered_df)
     if option == "4. Find days when oil price spiked and compare with Bitcoin price change.":
         filtered_df = pd.read_sql(" SELECT o.date, o.price_usd AS oil_price, (o.price_usd - LAG(o.price_usd) OVER (ORDER BY o.date)) AS oil_change, c.price_usd AS bitcoin_price, (c.price_usd - LAG(c.price_usd) OVER (ORDER BY c.date)) AS bitcoin_change FROM oil_prices o LEFT JOIN crypto_price c ON o.date = c.date WHERE c.coin_id='bitcoin' ORDER BY o.date;",con=conn)
         st.dataframe(filtered_df)
     if option == "5. Compare top 3 coins daily price trend vs Nifty (^NSEI).":
         filtered_df = pd.read_sql(" SELECT c.date, c.coin_id , c.price_usd AS crypto_price, s.close AS nifty_price FROM crypto_price c JOIN stock_prices s ON c.date = s.date WHERE c.coin_id IN ( SELECT coin_id FROM crypto_price GROUP BY coin_id ORDER BY AVG(price_usd) DESC LIMIT 3 ) AND s.ticker = '^NSEI' ORDER BY c.date;",con=conn)
         st.dataframe(filtered_df)
     if option == "6. Compare stock prices (^GSPC) with crude oil prices on the same dates":
         filtered_df = pd.read_sql("SELECT s.date, s.close AS sp500_close, o.price_usd AS oil_price FROM stock_prices s LEFT JOIN oil_prices o ON s.date = o.date WHERE s.ticker='^GSPC' GROUP BY s.date ORDER BY s.date;",con=conn)
         st.dataframe(filtered_df)
     if option == "7. Correlate Bitcoin closing price with crude oil closing price (same date)":
         filtered_df = pd.read_sql("SELECT c.date, c.price_usd AS bitcoin_price, o.price_usd AS oil_price FROM crypto_price c JOIN oil_prices o ON c.date = o.date WHERE c.coin_id='bitcoin' ORDER BY c.date;",con=conn)
         st.dataframe(filtered_df)
     if option == "8. Compare NASDAQ (^IXIC) with Ethereum price trends":
         filtered_df = pd.read_sql("SELECT  s.date, s.close AS nasdaq_close, c.price_usd AS ethereum_price FROM stock_prices s JOIN crypto_price c ON s.date = c.date WHERE s.ticker='^IXIC' AND c.coin_id='ethereum' ORDER BY s.date;",con=conn)
         st.dataframe(filtered_df)
     if option == "9. Join top 3 crypto coins with stock indices for 2025":
         filtered_df = pd.read_sql("SELECT c.date, c.coin_id, c.price_usd, s.ticker, s.close AS stock_close FROM crypto_price c JOIN stock_prices s ON c.date = s.date WHERE c.coin_id IN ('bitcoin','ethereum','tether') AND s.ticker IN ('^IXIC','^GSPC') AND strftime('%Y', c.date)='2025' ORDER BY c.date;",con=conn)
         st.dataframe(filtered_df)
     if option == "10. Multi-join: stock prices, oil prices, and Bitcoin prices for daily comparison":
         filtered_df = pd.read_sql("SELECT s.date, s.ticker, s.close AS stock_close, o.price_usd AS oil_price, c.price_usd AS bitcoin_price FROM stock_prices s JOIN oil_prices o ON s.date = o.date JOIN crypto_price c ON s.date = c.date WHERE s.ticker='^IXIC' AND c.coin_id='bitcoin' ORDER BY s.date;",con=conn)
         st.dataframe(filtered_df)

if selected == "Crypto Analysis":
    st.title("Cryptocurrency Price Dashboard")
# Select coin
    coin = st.selectbox(
    "Select Cryptocurrency",
    ["bitcoin","ethereum","tether"]
    )
    # Date filters
    start_date = st.date_input("Start Date")
    end_date = st.date_input("End Date")

# SQL Query
    query = """ SELECT date, price_usd FROM crypto_price WHERE coin_id = ? AND date BETWEEN ? AND ? ORDER BY date """
    df = pd.read_sql(query, conn, params=(coin, start_date, end_date))
# Show line chart
    st.subheader("Daily Price Trend")
    st.line_chart(df.set_index("date"))

# Show table
    st.subheader("Daily Price Table")
    st.dataframe(df)
# Out:
# Overwriting app.py

# %%
# !streamlit run /content/app.py &>/content/logs.txt &

# %%
# !grep -o 'https://.*\.trycloudflare.com' nohup.out | head -n 1 | xargs -I {} echo "Your tunnel url {}"
# Out:
# Your tunnel url https://statement-unavailable-starting-partial.trycloudflare.com

# %%
# !pip install pymysql

# %%
pd.read_sql("select * from oil_prices",con = conn)
# Out:
#       index        Date  price_usd
# 0      8569  2020-01-02      61.17
# 1      8570  2020-01-03      63.00
# 2      8571  2020-01-06      63.27
# 3      8572  2020-01-07      62.70
# 4      8573  2020-01-08      59.65
# ...     ...         ...        ...
# 1515  10084  2026-01-26      60.46
# 1516  10085  2026-01-27      62.04
# 1517  10086  2026-01-28      62.75
# 1518  10087  2026-01-29      64.77
# 1519  10088  2026-01-30      64.50
#
# [1520 rows x 3 columns]

# %%
pd.read_sql("select * from Crypto_price where coin_id = 'bitcoin' and date between '2025-04-01' and '2025-04-30'",con = conn)

#pd.read_sql("select * from oil_prices",con = conn)
# Out:
#     index  coin_id        date     price_usd
# 0       5  bitcoin  2025-04-01  82514.093654
# 1       6  bitcoin  2025-04-02  85237.587605
# 2       7  bitcoin  2025-04-03  82526.422153
# 3       8  bitcoin  2025-04-04  83163.987574
# 4       9  bitcoin  2025-04-05  83852.007654
# 5      10  bitcoin  2025-04-06  83595.885502
# 6      11  bitcoin  2025-04-07  78211.483582
# 7      12  bitcoin  2025-04-08  79179.292268
# 8      13  bitcoin  2025-04-09  76329.090356
# 9      14  bitcoin  2025-04-10  82622.170295
# 10     15  bitcoin  2025-04-11  79596.357323
# 11     16  bitcoin  2025-04-12  83439.288180
# 12     17  bitcoin  2025-04-13  85305.097284
# 13     18  bitcoin  2025-04-14  83600.820101
# 14     19  bitcoin  2025-04-15  84523.452491
# 15     20  bitcoin  2025-04-16  83656.492489
# 16     21  bitcoin  2025-04-17  84105.779422
# 17     22  bitcoin  2025-04-18  84930.908576
# 18     23  bitcoin  2025-04-19  84433.750172
# 19     24  bitcoin  2025-04-20  85126.662443
# ...

# %%
import sqlite3

conn = sqlite3.connect('ds.db')   # change the name of database accordingly
cursor = conn.cursor()

# %%
# Create a table
cursor.execute('''CREATE TABLE IF NOT EXISTS Cryptocurrencies (
    id VARCHAR(50) PRIMARY KEY,
    symbol VARCHAR(10),
    name VARCHAR(100),
    current_price DECIMAL(18, 6),
    market_cap BIGINT,
    market_cap_rank INT,
    total_volume BIGINT,
    circulating_supply DECIMAL(20, 6),
    total_supply DECIMAL(20, 6),
    ath DECIMAL(18, 6),
    atl DECIMAL(18, 6),
    date DATE
);

                ''')

# %%
data = list(cc.itertuples(index=False, name=None))

# %%
query = "INSERT INTO Cryptocurrencies ( id, symbol, name, current_price, market_cap, market_cap_rank, total_volume, circulating_supply, total_supply, ath, atl, date) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)"

cursor.executemany(query, data)

# Commit changes
conn.commit()
conn.close()

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('ds.db')   # change the name of database accordingly
cursor = conn.cursor()
df = pd.read_sql("SELECT * FROM Cryptocurrencies", conn)
df
conn.commit()
conn.close()

# %%
df
# Out:
#       index                id    symbol              name  current_price  \
# 0       0.0           bitcoin       btc           Bitcoin   69627.000000
# 1       1.0          ethereum       eth          Ethereum    2079.310000
# 2       2.0            tether      usdt            Tether       0.999558
# 3       3.0       binancecoin       bnb               BNB     631.180000
# 4       4.0            ripple       xrp               XRP       1.380000
# ...     ...               ...       ...               ...            ...
# 1495    NaN          pinksale  pinksale          PinkSale     237.350000
# 1496    NaN  particle-network     parti  Particle Network       0.102109
# 1497    NaN             anoma       xan             Anoma       0.009409
# 1498    NaN        omega-labs      sn24        OMEGA Labs       5.490000
# 1499    NaN          medibloc       med          Medibloc       0.002211
#
#          market_cap  market_cap_rank  total_volume  circulating_supply  \
# ...

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('ds.db')   # change the name of database accordingly
cursor = conn.cursor()
cursor.execute('''CREATE TABLE IF NOT EXISTS Crypto_prices (
    coin_id VARCHAR(50),
    date DATE,
    price_usd DECIMAL(18, 6),

    FOREIGN KEY (coin_id)
    REFERENCES Cryptocurrencies(id)
    ON DELETE CASCADE
    ON UPDATE CASCADE
);
             ''')

conn.commit()
conn.close()

# %%
data = list(cp.itertuples(index=False, name=None))

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('ds.db')
cursor = conn.cursor()
# Insert query
query = "INSERT INTO Crypto_prices (coin_id, date, price_usd) VALUES (?, ?,?)"

# Bulk insert
cursor.executemany(query, data)

# Commit changes
conn.commit()
conn.close()

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("ds.db")
df = pd.read_sql("SELECT coin_id,date,price_usd FROM Crypto_prices", conn)
df
# Out:
#       coin_id        date     price_usd
# 0     bitcoin  2025-03-27  86960.855549
# 1     bitcoin  2025-03-28  87227.271580
# 2     bitcoin  2025-03-29  84359.469155
# 3     bitcoin  2025-03-30  82679.172554
# 4     bitcoin  2025-03-31  82356.381112
# ...       ...         ...           ...
# 3289   tether  2026-03-23      0.999760
# 3290   tether  2026-03-24      0.999728
# 3291   tether  2026-03-25      0.999546
# 3292   tether  2026-03-26      0.999616
# 3293   tether  2026-03-26      0.999448
#
# [3294 rows x 3 columns]

# %%
df
# Out:
#       coin_id        date     price_usd
# 0     bitcoin  2025-03-27  86960.855549
# 1     bitcoin  2025-03-28  87227.271580
# 2     bitcoin  2025-03-29  84359.469155
# 3     bitcoin  2025-03-30  82679.172554
# 4     bitcoin  2025-03-31  82356.381112
# ...       ...         ...           ...
# 3289   tether  2026-03-23      0.999760
# 3290   tether  2026-03-24      0.999728
# 3291   tether  2026-03-25      0.999546
# 3292   tether  2026-03-26      0.999616
# 3293   tether  2026-03-26      0.999448
#
# [3294 rows x 3 columns]

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('ds.db')
cursor = conn.cursor()
cursor.execute('''CREATE TABLE IF NOT EXISTS oil_prices (date DATE PRIMARY KEY, price_usd DECIMAL(18, 6))''')

conn.commit()
conn.close()

# %%
data = list(filtered_df.itertuples(index=False, name=None))

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('ds.db')
cursor = conn.cursor()
# Insert query
query = "INSERT INTO oil_prices (date, price_usd) VALUES (?, ?)"

# Bulk insert
cursor.executemany(query, data)

# Commit changes
conn.commit()
conn.close()

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('ds.db')
cursor = conn.cursor()
df = pd.read_sql("SELECT Date,price_usd FROM Oil_prices", conn)

print(df)
# Out:
#             Date  price_usd
# 0     2020-01-02      61.17
# 1     2020-01-03      63.00
# 2     2020-01-06      63.27
# 3     2020-01-07      62.70
# 4     2020-01-08      59.65
# ...          ...        ...
# 3035  2026-01-26      60.46
# 3036  2026-01-27      62.04
# 3037  2026-01-28      62.75
# 3038  2026-01-29      64.77
# 3039  2026-01-30      64.50
#
# [3040 rows x 2 columns]

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("ds.db")
cursor = conn.cursor()
cursor.execute('''CREATE TABLE IF NOT EXISTS Stock_prices (
    date DATE,
    open DECIMAL(18, 6),
    high DECIMAL(18, 6),
    low DECIMAL(18, 6),
    close DECIMAL(18, 6),
    volume BIGINT,
    ticker VARCHAR(20)

);              ''')

# %%
data = list(all_stocks.itertuples(index=False, name=None))

# %%
# Insert query
query = "INSERT INTO Stock_prices (date,open, high, low, close,volume, ticker) VALUES (?, ?, ?, ?, ?, ?, ?)"

# Bulk insert
cursor.executemany(query, data)

# Commit changes
conn.commit()
conn.close()

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('ds.db')
cursor = conn.cursor()
df = pd.read_sql("SELECT * FROM Stock_prices", conn)
print(df)
conn.commit()
conn.close()
# Out:
#        index        Date          Open          High           Low  \
# 0        1.0  2020-01-02   3244.669922   3258.139893   3235.530029
# 1        2.0  2020-01-03   3226.360107   3246.149902   3222.340088
# 2        3.0  2020-01-06   3217.550049   3246.840088   3214.639893
# 3        4.0  2020-01-07   3241.860107   3244.909912   3232.429932
# 4        5.0  2020-01-08   3238.590088   3267.070068   3236.669922
# ...      ...         ...           ...           ...           ...
# 25849    NaN  2025-09-23  25209.000000  25261.900391  25084.650391
# 25850    NaN  2025-09-24  25108.750000  25149.849609  25027.449219
# 25851    NaN  2025-09-25  25034.500000  25092.699219  24878.300781
# 25852    NaN  2025-09-26  24818.550781  24868.599609  24629.449219
# 25853    NaN  2025-09-29  24728.550781  24791.300781  24606.199219
#
#               Close        Volume Ticker
# 0       3257.850098  3.459930e+09  ^GSPC
# 1       3234.850098  3.484700e+09  ^GSPC
# ...

# %%
df
# Out:
#        index        Date          Open          High           Low  \
# 0        1.0  2020-01-02   3244.669922   3258.139893   3235.530029
# 1        2.0  2020-01-03   3226.360107   3246.149902   3222.340088
# 2        3.0  2020-01-06   3217.550049   3246.840088   3214.639893
# 3        4.0  2020-01-07   3241.860107   3244.909912   3232.429932
# 4        5.0  2020-01-08   3238.590088   3267.070068   3236.669922
# ...      ...         ...           ...           ...           ...
# 25849    NaN  2025-09-23  25209.000000  25261.900391  25084.650391
# 25850    NaN  2025-09-24  25108.750000  25149.849609  25027.449219
# 25851    NaN  2025-09-25  25034.500000  25092.699219  24878.300781
# 25852    NaN  2025-09-26  24818.550781  24868.599609  24629.449219
# 25853    NaN  2025-09-29  24728.550781  24791.300781  24606.199219
#
#               Close        Volume Ticker
# 0       3257.850098  3.459930e+09  ^GSPC
# 1       3234.850098  3.484700e+09  ^GSPC
# ...
